# %%
from glob import glob
import pandas as pd 
import numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings         
warnings.filterwarnings('ignore')

# %%
path=pd.DataFrame(glob('C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagnostic-ecg-database-1.0.0/*'))

# %%
path.columns=['location']

# %%
path
# Out:
#                                               location
# 0    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 1    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 2    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 3    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 4    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# ..                                                 ...
# 290  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 291  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 292  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 293  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 294  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
#
# [295 rows x 1 columns]

# %%
path.info
# Out:
# <bound method DataFrame.info of                                               location
# 0    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 1    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 2    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 3    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 4    C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# ..                                                 ...
# 290  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 291  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 292  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 293  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 294  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
#
# [295 rows x 1 columns]>

# %%
path.head(5)
# Out:
#                                             location
# 0  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 1  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 2  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 3  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 4  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...

# %%
path.tail(5)
# Out:
#                                               location
# 290  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 291  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 292  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 293  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...
# 294  C:/Users/Lenovo/OneDrive/Desktop/mat/ptb-diagn...

# %%
path.shape
# Out:
# (295, 1)

# %%
import os
import wfdb

df=os.chdir('C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001')
record = wfdb.rdrecord('S0010_re', )
wfdb.plot_wfdb(record, figsize=(15,15))

# %%
#import os
#path_of_the_directory= 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001'
#print("S0010_re")
#for filename in os.listdir(path_of_the_directory):
    #f = os.path.join(path_of_the_directory,filename)
   # if os.path.isfile(f):
        #print(f)

# %% [markdown]
# # To implement a low-pass filter in Python, you can use the scipy library's signal module. The following code demonstrates how to create a low-pass filter using a Butterworth filter:
# In this code, we first define the sampling frequency fs and the cutoff frequency cutoff. We then calculate the normalized cutoff frequency normalized_cutoff using the Nyquist frequency.
#
# Next, we create a Butterworth filter of order 4 using the signal.butter() function. The btype parameter is set to 'lowpass' to create a low-pass filter.
#
# We generate some sample data by creating a signal consisting of two sine waves of frequencies 50 Hz and 150 Hz. We then apply the filter to this data using the signal.filtfilt() function. This function applies a filter to the data both forwards and backwards to remove any phase distortion introduced by the filter.
#
# Finally, we plot both the original and filtered signals using matplotlib.

# %%
import numpy as np
from scipy import signal

# Define the sampling frequency and cutoff frequency
fs = 1000 # Hz
cutoff = 100 # Hz

# Calculate the normalized cutoff frequency
nyq = 0.5 * fs
normalized_cutoff = cutoff / nyq

# Create the Butterworth filter
order = 4 # Filter order
b, a = signal.butter(order, normalized_cutoff, btype='lowpass')

# Generate some sample data
t = np.linspace(0, 1, 1000, endpoint=False)
x = np.sin(2 * np.pi * 50 * t) + np.sin(2 * np.pi * 180 * t)

# Apply the filter to the data
filtered_signal = signal.filtfilt(b, a, x)

# Plot the original and filtered signals
import matplotlib.pyplot as plt
fig, (ax_orig, ax_filtered) = plt.subplots(2, 1, sharex=True)
ax_orig.plot(t, x)
ax_orig.set_title('S0010_re')
ax_filtered.plot(t, filtered_signal)
ax_filtered.set_title('Filtered signal')
plt.show()

# %% [markdown]
# # To implement a high-pass filter in Python, you can use the scipy library's signal module. The following code demonstrates how to create a high-pass filter using a Butterworth filter:
# In this code, we first define the sampling frequency fs and the cutoff frequency cutoff. We then calculate the normalized cutoff frequency normalized_cutoff using the Nyquist frequency.
#
# Next, we create a Butterworth filter of order 4 using the signal.butter() function. The btype parameter is set to 'highpass' to create a high-pass filter.
#
# We generate some sample data by creating a signal consisting of two sine waves of frequencies 50 Hz and 150 Hz. We then apply the filter to this data using the signal.filtfilt() function. This function applies a filter to the data both forwards and backwards to remove any phase distortion introduced by the filter.
#
# Finally, we plot both the original and filtered signals using matplotlib.

# %%
import numpy as np
from scipy import signal

# Define the sampling frequency and cutoff frequency
fs = 1000 # Hz
cutoff = 100 # Hz

# Calculate the normalized cutoff frequency
nyq = 0.5 * fs
normalized_cutoff = cutoff / nyq

# Create the Butterworth filter
order = 4 # Filter order
b, a = signal.butter(order, normalized_cutoff, btype='highpass')

# Generate some sample data
t = np.linspace(0, 1, 1000, endpoint=False)
x = np.sin(2 * np.pi * 50 * t) + np.sin(2 * np.pi * 150 * t)

# Apply the filter to the data
filtered_signal = signal.filtfilt(b, a, x)

# Plot the original and filtered signals
import matplotlib.pyplot as plt
fig, (ax_orig, ax_filtered) = plt.subplots(2, 1, sharex=True)
ax_orig.plot(t, x)
ax_orig.set_title('Original signal')
ax_filtered.plot(t, filtered_signal)
ax_filtered.set_title('Filtered signal')
plt.show()

# %% [markdown]
# # To implement a band-pass filter in Python, you can use the scipy library's signal module. The following code demonstrates how to create a band-pass filter using a Butterworth filter:
# In this code, we first define the sampling frequency fs, the lower cutoff frequency lowcut, and the higher cutoff frequency highcut. We then calculate the normalized cutoff frequencies low and high using the Nyquist frequency.
#
# Next, we create a Butterworth filter of order 4 using the signal.butter() function. The btype parameter is set to 'bandpass' to create a band-pass filter. The Wn parameter is set to a list of [low, high] to specify the lower and upper cutoff frequencies.
#
# We generate some sample data by creating a signal consisting of two sine waves of frequencies 50 Hz and 150 Hz. We then apply the filter to this data using the signal.filtfilt() function. This function applies a filter to the data both forwards and backwards to remove any phase distortion introduced by the filter.
#
# Finally, we plot both the original and filtered signals using matplotlib.

# %%
import numpy as np
from scipy import signal

# Define the sampling frequency and band-pass filter parameters
fs = 1000 # Hz
lowcut = 50 # Hz
highcut = 150 # Hz

# Calculate the normalized cutoff frequencies
nyq = 0.5 * fs
low = lowcut / nyq
high = highcut / nyq

# Create the Butterworth filter
order = 4 # Filter order
b, a = signal.butter(order, [low, high], btype='bandpass')

# Generate some sample data
t = np.linspace(0, 1, 1000, endpoint=False)
x = np.sin(2 * np.pi * 50 * t) + np.sin(2 * np.pi * 150 * t)

# Apply the filter to the data
filtered_signal = signal.filtfilt(b, a, x)

# Plot the original and filtered signals
import matplotlib.pyplot as plt
fig, (ax_orig, ax_filtered) = plt.subplots(2, 1, sharex=True)
ax_orig.plot(t, x)
ax_orig.set_title('Original signal')
ax_filtered.plot(t, filtered_signal)
ax_filtered.set_title('Filtered signal')
plt.show()

# %%
pip install signal
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement signal (from versions: none)
# ERROR: No matching distribution found for signal
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install peaks
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement peaks (from versions: none)
# ERROR: No matching distribution found for peaks
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install signal peaks
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement signal (from versions: none)
# ERROR: No matching distribution found for signal
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\lenovo\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_12076/174338879.py", line 12
#     ecg_signal = record.p_signal.flatten()
#     ^
# SyntaxError: invalid syntax

# %%
import os
import wfdb
import matplotlib.pyplot as plt
os.chdir(r'C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001')
record=wfdb.rdrecord('s0010_re',channels=[3])
wfdb.plot_wfdb(record,figsize=(30,30))

from scipy import signal

# Load the ECG signal using WFDB
#record = wfdb.rdrecord(r'C:\Users\HP\Downloads\ptb-diagnostic-ecg-database-1.0.0\ptb-diagnostic-ecg-database-1.0.0\patient001/signal', channels=[0])

#record = wfdb.rdrecord('C:\Users\HP\Downloads\ptb-diagnostic-ecg-database-1.0.0\ptb-diagnostic-ecg-database-1.0.0\patient001/signal', channels=[0])
ecg_signal = record.p_signal.flatten()


# Set the filter parameters
filter_order = 7
cutoff_frequency = 0.2  # Hz

# Apply a low-pass filter to the ECG signal
b, a = signal.butter(filter_order, cutoff_frequency, 'low', fs=record.fs)
filtered_signal = signal.filtfilt(b, a, ecg_signal)

# Plot the original and filtered signals
plt.plot(ecg_signal, label='Original')
plt.plot(filtered_signal, label='Filtered')
plt.legend()
plt.show()

# %%
from math import sin,isnan
from pylab import *
import os
import wfdb
import matplotlib.pyplot as plt
os.chdir(r'C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001')
record=wfdb.rdrecord('s0010_re',channels=[3])
wfdb.plot_wfdb(record,figsize=(30,30))
def peakdet(v, delta,thresh,x):
    delta=abs(delta)
    maxtab = []
    mintab = []

    v = asarray(v)

    mn, mx = v[0], v[0]
    mnpos, mxpos = NaN, NaN

    lookformax = True

    for i in arange(len(v)):
        this = v[i]
        if abs(this)>thresh:
            if this > mx:
                mx = this
                mxpos = x[i]
            if this < mn:
                mn = this
                mnpos = x[i]
            if lookformax:
                if (this < mx-delta):
                    if (mx>abs(thresh)) and not isnan(mxpos):
                        maxtab.append((mxpos, mx))
                    mn = this
                    mnpos = x[i]
                    lookformax = False
            else:
                if (this > mn+delta):
                    if (mn<-abs(thresh)) and not isnan(mnpos):
                        mintab.append((mnpos, mn))
                    mx = this
                    mxpos = x[i]
                    lookformax = True
    return array(maxtab), array(mintab)

#Input Signal
t=array(range(50))
series=0.3*sin(t)+0.7*cos(2*t)-0.5*sin(1.2*t)

thresh=0.95 #Threshold value
delta=0.0 #

a=zeros(len(t)) #
a[:]=thresh #

maxtab, mintab = peakdet(series,delta,thresh,t)

#Plotting output
scatter(array(maxtab)[:,0], array(maxtab)[:,1], color='red')
scatter(array(mintab)[:,0], array(mintab)[:,1], color='blue')
xlim([0,t[-1]])
title('Peak Detector')
grid(True)
plot(t,a,color='green',linestyle='--',dashes=(5,3))
plot(t,-a,color='green',linestyle='--',dashes=(5,3))
annotate('Threshold',xy=(t[-1],thresh),fontsize=9)
plot(t,series,'k')
show()

# %%
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt

# Input signal
t = np.arange(100)
series = 0.3*np.sin(t)+0.7*np.cos(2*t)-0.5*np.sin(1.2*t)

# Threshold value (for height of peaks and valleys)
thresh = 0.95

# Find indices of peaks
peak_idx, _ = find_peaks(series, height=thresh)

# Find indices of valleys (from inverting the signal)
valley_idx, _ = find_peaks(-series, height=thresh)

# Plot signal
plt.plot(t, series)

# Plot threshold
plt.plot([min(t), max(t)], [thresh, thresh], '--')
plt.plot([min(t), max(t)], [-thresh, -thresh], '--')

# Plot peaks (red) and valleys (blue)
plt.plot(t[peak_idx], series[peak_idx], 'r.')
plt.plot(t[valley_idx], series[valley_idx], 'b.')

plt.show()

# %%
from math import sin
from matplotlib import pylab
from pylab import *

def peakdet(v, thresh):
    maxthresh = []
    minthresh = []
    peaks = []
    valleys = []

    for x, y in v:
        if y > thresh:
            maxthresh.append((x, y))
        elif y < -thresh:
            minthresh.append((x, y))

    for x, y in maxthresh:
        try:
            if (v[x - 1][1] < y) & (v[x + 1][1] < y):
                peaks.append((x, y))
        except Exception:
            pass

    for x, y in minthresh:
        try:
            if (v[x - 1][1] > y) & (v[x + 1][1] > y):
                valleys.append((x, y))
        except Exception:
            pass

    return peaks, valleys

# %%
# input signal
t = array(range(100))
series = 0.3 * sin(t) + 0.7 * cos(2 * t) - 0.5 * sin(1.2 * t)

arr = [*zip(t, series)]  # create a list of tuples where the tuples represent the (x, y) values of the function
thresh = 0.95

peaks, valleys = peakdet(arr, thresh)

scatter([x for x, y in peaks], [y for x, y in peaks], color = 'red')
scatter([x for x, y in valleys], [y for x, y in valleys], color = 'blue')
plot(t, 100 * [thresh], color='green', linestyle='--', dashes=(5, 3))
plot(t, 100 * [-thresh], color='green', linestyle='--', dashes=(5, 3))
plot(t, series, 'k')
show()

# %%
# input signal
t = array(range(100))
series = 6.3 * sin(t) + 4.7 * cos(2 * t) - 3.5 * sin(1.2 * t)

arr = [*zip(t, series)]
thresh = 0.95

peaks, valleys = peakdet(arr, thresh)

scatter([x for x, y in peaks], [y for x, y in peaks], color = 'red')
scatter([x for x, y in valleys], [y for x, y in valleys], color = 'blue')
plot(t, 100 * [thresh], color='black', linestyle='--', dashes=(5, 3))
plot(t, 100 * [-thresh], color='black', linestyle='--', dashes=(5, 3))
plot(t, series, 'k')
show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# input signal
x = np.arange(1,100,1)
y = 0.3 * np.sin(x) + 0.7 * np.cos(2 * x) - 0.5 * np.sin(1.2 * x)
threshold = 0.95

# max
maxi = np.where(np.where([(y - np.roll(y,1) > 0) & (y - np.roll(y,-1) > 0)],y, 0)> threshold, y,np.nan)
# min
mini = np.where(np.where([(y - np.roll(y,1) < 0) & (y - np.roll(y,-1) < 0)],y, 0)< -threshold, y,np.nan)

# %%
#@title Choose ECG Signal { form-width: "20%", display-mode: "both" }
signal_number = 3 #@param {type:"slider", min:0, max:9, step:1}
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import sys

filename = 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001'/{str(100 + signal_number)}'
record = wfdb.rdrecord(filename, sampfrom=180, sampto=4000,)    
annotation = wfdb.rdann(filename, 'atr', sampfrom=180, sampto=4000,shift_samps=True)

wfdb.plot_wfdb(record=record, annotation=annotation,figsize=(15,8))
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp/ipykernel_14368/158152835.py", line 10
#     filename = 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\mat\\ptb-diagnostic-ecg-database-1.0.0\patient001'/{str(100 + signal_number)}'
#                                                                                                                                     ^
# SyntaxError: EOL while scanning string literal
